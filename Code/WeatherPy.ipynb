# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
import scipy.stats as st


# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 576

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = url + "appid=" + weather_api_key + "&q=" + city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | okha
# Processing Record 3 of Set 1 | ponta delgada
# Processing Record 4 of Set 1 | blackmans bay
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | tateyama
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | klyuchi
# Processing Record 9 of Set 1 | alamosa
# Processing Record 10 of Set 1 | greymouth
# Processing Record 11 of Set 1 | amga
# Processing Record 12 of Set 1 | hamilton
# Processing Record 13 of Set 1 | trevelin
# Processing Record 14 of Set 1 | sola
# Processing Record 15 of Set 1 | emerald
# Processing Record 16 of Set 1 | puerto natales
# Processing Record 17 of Set 1 | igbor
# Processing Record 18 of Set 1 | flekkefjord
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | edinburgh of the seven seas
# Processing Record 21 of Set 1 | kodiak
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | inhambane
# Processing Record 25 of Set 1 | utrik
# Processing Record 26 of Set 1 | coahuayana de hidalgo
# Processing Record 27 of Set 1 | zaozersk
# Processing Record 28 of Set 1 | whitehorse
# Processing Record 29 of Set 1 | santa catalina
# Processing Record 30 of Set 1 | tura
# Processing Record 31 of Set 1 | waitangi
# Processing Record 32 of Set 1 | karasu
# Processing Record 33 of Set 1 | ola
# Processing Record 34 of Set 1 | isafjordur
# Processing Record 35 of Set 1 | papatowai
# Processing Record 36 of Set 1 | nichinan
# Processing Record 37 of Set 1 | wynne
# Processing Record 38 of Set 1 | port-aux-francais
# Processing Record 39 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 40 of Set 1 | richards bay
# Processing Record 41 of Set 1 | espargos
# City not found. Skipping...
# Processing Record 42 of Set 1 | vernon
# Processing Record 43 of Set 1 | solnechnyy
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | kathmandu
# Processing Record 46 of Set 1 | marchtrenk
# Processing Record 47 of Set 1 | itaituba
# Processing Record 48 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 49 of Set 1 | chinde
# Processing Record 50 of Set 1 | hede
# Processing Record 0 of Set 2 | margaret river
# Processing Record 1 of Set 2 | jackson
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | dubrowna
# Processing Record 4 of Set 2 | mangrol
# Processing Record 5 of Set 2 | sabzevar
# Processing Record 6 of Set 2 | yoshikawa
# Processing Record 7 of Set 2 | saint-pierre-d'oleron
# City not found. Skipping...
# Processing Record 8 of Set 2 | kavieng
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | sungai besar
# Processing Record 11 of Set 2 | santa cruz
# Processing Record 12 of Set 2 | invercargill
# Processing Record 13 of Set 2 | wuwei
# Processing Record 14 of Set 2 | colonia
# Processing Record 15 of Set 2 | nova vicosa
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | okhotsk
# Processing Record 18 of Set 2 | qamdo
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | kamaishi
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | morehead city
# Processing Record 23 of Set 2 | lae
# Processing Record 24 of Set 2 | grytviken
# Processing Record 25 of Set 2 | petrolina
# Processing Record 26 of Set 2 | college
# Processing Record 27 of Set 2 | stanley
# Processing Record 28 of Set 2 | uturoa
# Processing Record 29 of Set 2 | ust-tsilma
# Processing Record 30 of Set 2 | bilibino
# Processing Record 31 of Set 2 | longyearbyen
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | meadow lakes
# Processing Record 34 of Set 2 | coquimbo
# Processing Record 35 of Set 2 | mogocha
# Processing Record 36 of Set 2 | serafimovskiy
# Processing Record 37 of Set 2 | progreso
# Processing Record 38 of Set 2 | bel ombre
# Processing Record 39 of Set 2 | union de tula
# Processing Record 40 of Set 2 | buala
# Processing Record 41 of Set 2 | angaur state
# Processing Record 42 of Set 2 | shakiso
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | papao
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | mount gambier
# Processing Record 47 of Set 2 | bandarbeyla
# Processing Record 48 of Set 2 | setti fatma
# City not found. Skipping...
# Processing Record 49 of Set 2 | geraldton
# Processing Record 0 of Set 3 | madimba
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | aswan
# Processing Record 3 of Set 3 | bundi
# Processing Record 4 of Set 3 | agat village
# Processing Record 5 of Set 3 | ouesso
# Processing Record 6 of Set 3 | amos
# Processing Record 7 of Set 3 | san antonio
# Processing Record 8 of Set 3 | lospalos
# Processing Record 9 of Set 3 | flin flon
# Processing Record 10 of Set 3 | petrozavodsk
# Processing Record 11 of Set 3 | la serena
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | huarmey
# Processing Record 14 of Set 3 | betioky
# Processing Record 15 of Set 3 | alice springs
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | san patricio
# Processing Record 18 of Set 3 | brokopondo
# Processing Record 19 of Set 3 | new norfolk
# Processing Record 20 of Set 3 | saint-francois
# Processing Record 21 of Set 3 | wailua homesteads
# Processing Record 22 of Set 3 | igarka
# Processing Record 23 of Set 3 | ta`u
# Processing Record 24 of Set 3 | saint-philippe
# Processing Record 25 of Set 3 | shuangjiang
# Processing Record 26 of Set 3 | nchelenge
# Processing Record 27 of Set 3 | uruzgan
# Processing Record 28 of Set 3 | hilo
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | merizo village
# Processing Record 31 of Set 3 | vilyuchinsk
# Processing Record 32 of Set 3 | severobaykal'sk
# Processing Record 33 of Set 3 | constantia
# Processing Record 34 of Set 3 | norrtalje
# Processing Record 35 of Set 3 | dunedin
# Processing Record 36 of Set 3 | gadzhiyevo
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | beau vallon
# Processing Record 39 of Set 3 | luderitz
# Processing Record 40 of Set 3 | homer
# Processing Record 41 of Set 3 | pandan
# Processing Record 42 of Set 3 | armacao de buzios
# Processing Record 43 of Set 3 | kingscliff
# Processing Record 44 of Set 3 | malakal
# Processing Record 45 of Set 3 | cooma
# Processing Record 46 of Set 3 | hagere maryam
# Processing Record 47 of Set 3 | popondetta
# Processing Record 48 of Set 3 | kobryn
# Processing Record 49 of Set 3 | yagry
# City not found. Skipping...
# Processing Record 0 of Set 4 | kerikeri
# Processing Record 1 of Set 4 | port mathurin
# Processing Record 2 of Set 4 | west island
# Processing Record 3 of Set 4 | port lincoln
# Processing Record 4 of Set 4 | aitape
# Processing Record 5 of Set 4 | sandnessjoen
# Processing Record 6 of Set 4 | beloyarskiy
# Processing Record 7 of Set 4 | ma'rib
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | vadso
# Processing Record 10 of Set 4 | castelo do piaui
# Processing Record 11 of Set 4 | koksan
# Processing Record 12 of Set 4 | sittwe
# Processing Record 13 of Set 4 | plettenberg bay
# Processing Record 14 of Set 4 | peace river
# Processing Record 15 of Set 4 | anadyr
# Processing Record 16 of Set 4 | newman
# Processing Record 17 of Set 4 | vorgashor
# Processing Record 18 of Set 4 | vila do maio
# Processing Record 19 of Set 4 | craig
# Processing Record 20 of Set 4 | kismayo
# Processing Record 21 of Set 4 | nar'yan-mar
# Processing Record 22 of Set 4 | talnakh
# Processing Record 23 of Set 4 | rosetta
# Processing Record 24 of Set 4 | kencong
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | anloga
# Processing Record 27 of Set 4 | lhasa
# Processing Record 28 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 29 of Set 4 | xiannu
# Processing Record 30 of Set 4 | goundi
# Processing Record 31 of Set 4 | puerto baquerizo moreno
# Processing Record 32 of Set 4 | ji'an
# Processing Record 33 of Set 4 | at taraf
# Processing Record 34 of Set 4 | liepaja
# Processing Record 35 of Set 4 | misliyah
# Processing Record 36 of Set 4 | west busselton
# City not found. Skipping...
# Processing Record 37 of Set 4 | al jawf
# Processing Record 38 of Set 4 | aasiaat
# Processing Record 39 of Set 4 | tidjikja
# Processing Record 40 of Set 4 | hammerfest
# Processing Record 41 of Set 4 | burang
# Processing Record 42 of Set 4 | antsiranana
# Processing Record 43 of Set 4 | ust-nera
# Processing Record 44 of Set 4 | pionerskiy
# Processing Record 45 of Set 4 | arawa
# Processing Record 46 of Set 4 | sydney
# Processing Record 47 of Set 4 | saipan
# Processing Record 48 of Set 4 | meppel
# Processing Record 49 of Set 4 | bodo
# Processing Record 0 of Set 5 | st. john's
# Processing Record 1 of Set 5 | vila velha
# Processing Record 2 of Set 5 | kamien pomorski
# Processing Record 3 of Set 5 | parry sound
# Processing Record 4 of Set 5 | tsiombe
# Processing Record 5 of Set 5 | enewetak
# Processing Record 6 of Set 5 | hithadhoo
# Processing Record 7 of Set 5 | whangarei
# Processing Record 8 of Set 5 | pisco
# Processing Record 9 of Set 5 | howrah
# Processing Record 10 of Set 5 | caraballeda
# Processing Record 11 of Set 5 | tazacorte
# Processing Record 12 of Set 5 | palikir - national government center
# Processing Record 13 of Set 5 | camargo
# Processing Record 14 of Set 5 | la passe
# Processing Record 15 of Set 5 | puerto ayora
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | udachny
# Processing Record 18 of Set 5 | shengli
# Processing Record 19 of Set 5 | estacion coahuila
# Processing Record 20 of Set 5 | mildura
# Processing Record 21 of Set 5 | morant bay
# Processing Record 22 of Set 5 | qui nhon
# Processing Record 23 of Set 5 | port augusta
# Processing Record 24 of Set 5 | oroqen zizhiqi
# Processing Record 25 of Set 5 | dilling
# Processing Record 26 of Set 5 | alderetes
# Processing Record 27 of Set 5 | lihue
# Processing Record 28 of Set 5 | afaahiti
# Processing Record 29 of Set 5 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 30 of Set 5 | mutuali
# Processing Record 31 of Set 5 | mawu
# Processing Record 32 of Set 5 | crane
# Processing Record 33 of Set 5 | badger
# Processing Record 34 of Set 5 | nuuk
# Processing Record 35 of Set 5 | padang
# Processing Record 36 of Set 5 | yeppoon
# Processing Record 37 of Set 5 | jaswantnagar
# Processing Record 38 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 39 of Set 5 | nieuw amsterdam
# Processing Record 40 of Set 5 | giengen an der brenz
# Processing Record 41 of Set 5 | cam ranh
# Processing Record 42 of Set 5 | as sulayyil
# Processing Record 43 of Set 5 | susuman
# Processing Record 44 of Set 5 | olonkinbyen
# Processing Record 45 of Set 5 | arar
# Processing Record 46 of Set 5 | mahabe
# City not found. Skipping...
# Processing Record 47 of Set 5 | chibougamau
# Processing Record 48 of Set 5 | gokwe
# Processing Record 49 of Set 5 | san antonio de pale
# Processing Record 0 of Set 6 | qaqortoq
# Processing Record 1 of Set 6 | panambi
# Processing Record 2 of Set 6 | williston
# Processing Record 3 of Set 6 | falmouth
# Processing Record 4 of Set 6 | mongo
# Processing Record 5 of Set 6 | navolato
# Processing Record 6 of Set 6 | acapulco de juarez
# Processing Record 7 of Set 6 | am djarass
# City not found. Skipping...
# Processing Record 8 of Set 6 | kruisfontein
# Processing Record 9 of Set 6 | timimoun
# Processing Record 10 of Set 6 | flying fish cove
# Processing Record 11 of Set 6 | klaksvik
# Processing Record 12 of Set 6 | yaren
# Processing Record 13 of Set 6 | timbuktu
# Processing Record 14 of Set 6 | oualidia
# City not found. Skipping...
# Processing Record 15 of Set 6 | ballina
# Processing Record 16 of Set 6 | sinop
# Processing Record 17 of Set 6 | dudinka
# Processing Record 18 of Set 6 | ploudalmezeau
# Processing Record 19 of Set 6 | hawaiian paradise park
# Processing Record 20 of Set 6 | alaghsas
# Processing Record 21 of Set 6 | carnarvon
# Processing Record 22 of Set 6 | shache
# Processing Record 23 of Set 6 | hirara
# Processing Record 24 of Set 6 | lazaro cardenas
# Processing Record 25 of Set 6 | laguna
# Processing Record 26 of Set 6 | ajaigarh
# Processing Record 27 of Set 6 | touros
# Processing Record 28 of Set 6 | hashtrud
# Processing Record 29 of Set 6 | caleta de carquin
# Processing Record 30 of Set 6 | ceerigaabo
# Processing Record 31 of Set 6 | santa elena de uairen
# Processing Record 32 of Set 6 | saldanha
# Processing Record 33 of Set 6 | kristiansund
# Processing Record 34 of Set 6 | puerto san jose
# Processing Record 35 of Set 6 | bechar
# Processing Record 36 of Set 6 | nuku'alofa
# Processing Record 37 of Set 6 | zapala
# Processing Record 38 of Set 6 | lalibela
# Processing Record 39 of Set 6 | mejit
# Processing Record 40 of Set 6 | turpan
# Processing Record 41 of Set 6 | punta cana
# Processing Record 42 of Set 6 | el granada
# Processing Record 43 of Set 6 | agropoli
# Processing Record 44 of Set 6 | sao joao da barra
# Processing Record 45 of Set 6 | kalifornsky
# Processing Record 46 of Set 6 | pangoa
# Processing Record 47 of Set 6 | puerto aysen
# Processing Record 48 of Set 6 | rottingdean
# Processing Record 49 of Set 6 | inongo
# Processing Record 0 of Set 7 | bridgewater
# Processing Record 1 of Set 7 | tolanaro
# Processing Record 2 of Set 7 | chonchi
# Processing Record 3 of Set 7 | burley
# Processing Record 4 of Set 7 | jamaame
# Processing Record 5 of Set 7 | uwajima
# Processing Record 6 of Set 7 | robore
# Processing Record 7 of Set 7 | lorengau
# Processing Record 8 of Set 7 | london
# Processing Record 9 of Set 7 | sumbawa besar
# Processing Record 10 of Set 7 | quibdo
# Processing Record 11 of Set 7 | poronaysk
# Processing Record 12 of Set 7 | santiago de cao
# Processing Record 13 of Set 7 | kodinar
# Processing Record 14 of Set 7 | huocheng
# City not found. Skipping...
# Processing Record 15 of Set 7 | mumbwa
# Processing Record 16 of Set 7 | temiskaming shores
# Processing Record 17 of Set 7 | wake village
# Processing Record 18 of Set 7 | yorkton
# Processing Record 19 of Set 7 | ketchikan
# Processing Record 20 of Set 7 | lerwick
# Processing Record 21 of Set 7 | peniche
# Processing Record 22 of Set 7 | medina
# Processing Record 23 of Set 7 | zhangye
# Processing Record 24 of Set 7 | leava
# Processing Record 25 of Set 7 | nanao
# Processing Record 26 of Set 7 | kalamata
# Processing Record 27 of Set 7 | lamin
# Processing Record 28 of Set 7 | rabo de peixe
# Processing Record 29 of Set 7 | margate
# Processing Record 30 of Set 7 | terrace
# Processing Record 31 of Set 7 | key west
# Processing Record 32 of Set 7 | champerico
# Processing Record 33 of Set 7 | jatai
# Processing Record 34 of Set 7 | egilsstadir
# Processing Record 35 of Set 7 | vorkuta
# Processing Record 36 of Set 7 | laojunmiao
# Processing Record 37 of Set 7 | palmer
# Processing Record 38 of Set 7 | kharan
# Processing Record 39 of Set 7 | polyarnyy
# Processing Record 40 of Set 7 | kuchinda
# Processing Record 41 of Set 7 | kailua-kona
# Processing Record 42 of Set 7 | huautla de jimenez
# Processing Record 43 of Set 7 | korla
# Processing Record 44 of Set 7 | chandbali
# Processing Record 45 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 46 of Set 7 | tazovsky
# Processing Record 47 of Set 7 | taltal
# Processing Record 48 of Set 7 | callao
# Processing Record 49 of Set 7 | mount isa
# Processing Record 0 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 1 of Set 8 | kayangel
# Processing Record 2 of Set 8 | cudillero
# Processing Record 3 of Set 8 | kapa'a
# Processing Record 4 of Set 8 | east london
# Processing Record 5 of Set 8 | enriquillo
# Processing Record 6 of Set 8 | shingu
# Processing Record 7 of Set 8 | harper
# Processing Record 8 of Set 8 | selfoss
# Processing Record 9 of Set 8 | rabaul
# Processing Record 10 of Set 8 | subaykhan
# Processing Record 11 of Set 8 | leiyang
# Processing Record 12 of Set 8 | kenai
# Processing Record 13 of Set 8 | petoskey
# Processing Record 14 of Set 8 | sumbe
# Processing Record 15 of Set 8 | kani keli
# Processing Record 16 of Set 8 | klang
# Processing Record 17 of Set 8 | tommot
# Processing Record 18 of Set 8 | potcoava
# Processing Record 19 of Set 8 | fort bragg
# Processing Record 20 of Set 8 | tawau
# Processing Record 21 of Set 8 | copiapo
# Processing Record 22 of Set 8 | tuy hoa
# Processing Record 23 of Set 8 | freetown
# Processing Record 24 of Set 8 | brookings
# Processing Record 25 of Set 8 | port shepstone
# Processing Record 26 of Set 8 | hasaki
# Processing Record 27 of Set 8 | boulder city
# Processing Record 28 of Set 8 | jiangkou
# Processing Record 29 of Set 8 | sarichioi
# Processing Record 30 of Set 8 | vidisha
# Processing Record 31 of Set 8 | kingston
# Processing Record 32 of Set 8 | nurota
# Processing Record 33 of Set 8 | charters towers
# Processing Record 34 of Set 8 | bikenibeu village
# Processing Record 35 of Set 8 | kisangani
# Processing Record 36 of Set 8 | pitimbu
# Processing Record 37 of Set 8 | prince george
# Processing Record 38 of Set 8 | valderice
# Processing Record 39 of Set 8 | urzhar
# Processing Record 40 of Set 8 | petauke
# Processing Record 41 of Set 8 | broken hill
# Processing Record 42 of Set 8 | dunay
# Processing Record 43 of Set 8 | tranas
# Processing Record 44 of Set 8 | novodvinsk
# Processing Record 45 of Set 8 | porto novo
# Processing Record 46 of Set 8 | the pas
# Processing Record 47 of Set 8 | an nuhud
# Processing Record 48 of Set 8 | iskateley
# Processing Record 49 of Set 8 | bayanaul
# Processing Record 0 of Set 9 | katsuren-haebaru
# Processing Record 1 of Set 9 | khandyga
# Processing Record 2 of Set 9 | bubaque
# Processing Record 3 of Set 9 | shahrud
# Processing Record 4 of Set 9 | berdigestyakh
# Processing Record 5 of Set 9 | siavonga
# Processing Record 6 of Set 9 | sterling
# Processing Record 7 of Set 9 | kumla
# Processing Record 8 of Set 9 | el tarf
# Processing Record 9 of Set 9 | dalian
# Processing Record 10 of Set 9 | shizuishan
# Processing Record 11 of Set 9 | bandar lampung
# Processing Record 12 of Set 9 | buka
# Processing Record 13 of Set 9 | razampeta
# Processing Record 14 of Set 9 | bourg-saint-andeol
# Processing Record 15 of Set 9 | piton saint-leu
# Processing Record 16 of Set 9 | queenstown
# Processing Record 17 of Set 9 | safford
# Processing Record 18 of Set 9 | salinopolis
# Processing Record 19 of Set 9 | kabarnet
# Processing Record 20 of Set 9 | victoria falls
# Processing Record 21 of Set 9 | mishkovo-pohorilove
# Processing Record 22 of Set 9 | sinabang
# Processing Record 23 of Set 9 | tadine
# Processing Record 24 of Set 9 | tyukhtet
# Processing Record 25 of Set 9 | acarau
# Processing Record 26 of Set 9 | lebowakgomo
# Processing Record 27 of Set 9 | qinggang
# Processing Record 28 of Set 9 | markaz-e hukumat-e darweshan
# Processing Record 29 of Set 9 | oxapampa
# Processing Record 30 of Set 9 | fort mcmurray
# Processing Record 31 of Set 9 | al artawiyah
# Processing Record 32 of Set 9 | vanimo
# Processing Record 33 of Set 9 | kembe
# Processing Record 34 of Set 9 | undurkhaan
# Processing Record 35 of Set 9 | skowhegan
# Processing Record 36 of Set 9 | sao jose da coroa grande
# Processing Record 37 of Set 9 | thief river falls
# Processing Record 38 of Set 9 | piacabucu
# Processing Record 39 of Set 9 | sisimiut
# Processing Record 40 of Set 9 | korpilahti
# Processing Record 41 of Set 9 | rabigh
# Processing Record 42 of Set 9 | cannonvale
# Processing Record 43 of Set 9 | mazatlan
# Processing Record 44 of Set 9 | yigo village
# Processing Record 45 of Set 9 | kavalerovo
# Processing Record 46 of Set 9 | muncar
# Processing Record 47 of Set 9 | las tablas
# Processing Record 48 of Set 9 | mar del plata
# Processing Record 49 of Set 9 | simplicio mendes
# Processing Record 0 of Set 10 | nemuro
# Processing Record 1 of Set 10 | charlottetown
# Processing Record 2 of Set 10 | pacific grove
# Processing Record 3 of Set 10 | les cayes
# Processing Record 4 of Set 10 | pyapon
# Processing Record 5 of Set 10 | weno
# Processing Record 6 of Set 10 | namdrik
# Processing Record 7 of Set 10 | ixtapa
# Processing Record 8 of Set 10 | sakakah
# Processing Record 9 of Set 10 | ghanzi
# Processing Record 10 of Set 10 | fort st. john
# Processing Record 11 of Set 10 | rockport
# Processing Record 12 of Set 10 | yunyang
# Processing Record 13 of Set 10 | belmonte
# Processing Record 14 of Set 10 | arraial do cabo
# Processing Record 15 of Set 10 | massawa
# Processing Record 16 of Set 10 | naze
# Processing Record 17 of Set 10 | mabaruma
# Processing Record 18 of Set 10 | labytnangi
# Processing Record 19 of Set 10 | pederneiras
# Processing Record 20 of Set 10 | takab
# Processing Record 21 of Set 10 | wewak
# Processing Record 22 of Set 10 | smithers
# Processing Record 23 of Set 10 | ljusdal
# Processing Record 24 of Set 10 | istaravshan
# Processing Record 25 of Set 10 | illizi
# Processing Record 26 of Set 10 | quellon
# Processing Record 27 of Set 10 | ghadamis
# Processing Record 28 of Set 10 | ulanhot
# Processing Record 29 of Set 10 | buzuluk
# Processing Record 30 of Set 10 | grand falls-windsor
# Processing Record 31 of Set 10 | changji
# Processing Record 32 of Set 10 | shagonar
# Processing Record 33 of Set 10 | charata
# Processing Record 34 of Set 10 | mahajanga
# Processing Record 35 of Set 10 | waddan
# Processing Record 36 of Set 10 | camayenne
# Processing Record 37 of Set 10 | nacala
# Processing Record 38 of Set 10 | ad dilam
# Processing Record 39 of Set 10 | bocas del toro
# Processing Record 40 of Set 10 | heideck
# Processing Record 41 of Set 10 | alofi
# Processing Record 42 of Set 10 | kindu
# Processing Record 43 of Set 10 | codrington
# Processing Record 44 of Set 10 | wajir
# Processing Record 45 of Set 10 | segezha
# Processing Record 46 of Set 10 | nantucket
# Processing Record 47 of Set 10 | puerto penasco
# Processing Record 48 of Set 10 | kazerun
# Processing Record 49 of Set 10 | zag
# Processing Record 0 of Set 11 | opuwo
# Processing Record 1 of Set 11 | krasnogorskoye
# Processing Record 2 of Set 11 | tual
# Processing Record 3 of Set 11 | corner brook
# Processing Record 4 of Set 11 | gurupi
# Processing Record 5 of Set 11 | posto fiscal rolim de moura
# Processing Record 6 of Set 11 | atafu village
# Processing Record 7 of Set 11 | howard springs
# Processing Record 8 of Set 11 | rio grande
# Processing Record 9 of Set 11 | yuzhno-kurilsk
# Processing Record 10 of Set 11 | recco
# Processing Record 11 of Set 11 | ugoofaaru
# Processing Record 12 of Set 11 | joshimath
# Processing Record 13 of Set 11 | kaa-khem
# Processing Record 14 of Set 11 | mukah
# City not found. Skipping...
# Processing Record 15 of Set 11 | klyavlino
# Processing Record 16 of Set 11 | dapa
# Processing Record 17 of Set 11 | roma
# Processing Record 18 of Set 11 | korocha
# Processing Record 19 of Set 11 | xinyuan
# Processing Record 20 of Set 11 | sao lourenco da serra
# Processing Record 21 of Set 11 | nova sintra
# Processing Record 22 of Set 11 | bocaiuva
# Processing Record 23 of Set 11 | pacocha
# Processing Record 24 of Set 11 | chabahar
# Processing Record 25 of Set 11 | thunder bay
# Processing Record 26 of Set 11 | slavyanka
# Processing Record 27 of Set 11 | tannum sands
# Processing Record 28 of Set 11 | sitka
# Processing Record 29 of Set 11 | fortuna
# Processing Record 30 of Set 11 | noumea
# Processing Record 31 of Set 11 | mahina
# Processing Record 32 of Set 11 | barranca
# Processing Record 33 of Set 11 | crossville
# Processing Record 34 of Set 11 | ulaangom
# Processing Record 35 of Set 11 | baker city
# Processing Record 36 of Set 11 | mersa matruh
# Processing Record 37 of Set 11 | arno
# Processing Record 38 of Set 11 | punta arenas
# Processing Record 39 of Set 11 | poyang
# Processing Record 40 of Set 11 | al-`ula
# City not found. Skipping...
# Processing Record 41 of Set 11 | padangsidempuan
# Processing Record 42 of Set 11 | yarmouth
# Processing Record 43 of Set 11 | altkirch
# Processing Record 44 of Set 11 | zabaykal'sk
# Processing Record 45 of Set 11 | jalai nur
# Processing Record 46 of Set 11 | levuka
# Processing Record 47 of Set 11 | sevastopol
# Processing Record 48 of Set 11 | kawambwa
# Processing Record 49 of Set 11 | fredericksburg
# Processing Record 0 of Set 12 | lindsay
# Processing Record 1 of Set 12 | carauari
# Processing Record 2 of Set 12 | oranjemund
# Processing Record 3 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 4 of Set 12 | bonab
# Processing Record 5 of Set 12 | jiayuguan
# Processing Record 6 of Set 12 | kununurra
# Processing Record 7 of Set 12 | sulak
# Processing Record 8 of Set 12 | tosontsengel
# Processing Record 9 of Set 12 | karaton
# Processing Record 10 of Set 12 | mount pleasant
# Processing Record 11 of Set 12 | nalut
# Processing Record 12 of Set 12 | springbok
# Processing Record 13 of Set 12 | dalbandin
# Processing Record 14 of Set 12 | hakha
# Processing Record 15 of Set 12 | chicoana
# Processing Record 16 of Set 12 | jiangzi
# Processing Record 17 of Set 12 | san carlos
# Processing Record 18 of Set 12 | barra de santo antonio
# Processing Record 19 of Set 12 | pangai
# Processing Record 20 of Set 12 | bella union
# Processing Record 21 of Set 12 | jiuquan
# Processing Record 22 of Set 12 | ribeira brava
# Processing Record 23 of Set 12 | severo-yeniseyskiy
# Processing Record 24 of Set 12 | dhidhdhoo
# Processing Record 25 of Set 12 | pariaman
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      adamstown -25.0660 -130.1015     25.01        89          99
# 1           okha  53.5739  142.9478    -24.72       100          97
# 2  ponta delgada  37.7333  -25.6667     18.44        88          20
# 3  blackmans bay -43.0167  147.3167     14.29        89         100
# 4        ushuaia -54.8000  -68.3000      8.81        76         100
#
#    Wind Speed Country        Date
# 0       11.31      PN  1707675265
# 1        1.81      RU  1707675389
# 2        7.20      PT  1707675389
# 3        1.36      AU  1707675389
# 4       11.32      AR  1707675126

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            adamstown -25.0660 -130.1015     25.01        89          99
# 1                 okha  53.5739  142.9478    -24.72       100          97
# 2        ponta delgada  37.7333  -25.6667     18.44        88          20
# 3        blackmans bay -43.0167  147.3167     14.29        89         100
# 4              ushuaia -54.8000  -68.3000      8.81        76         100
#
#          Wind Speed Country        Date
# City_ID
# 0             11.31      PN  1707675265
# 1              1.81      RU  1707675389
# 2              7.20      PT  1707675389
# 3              1.36      AU  1707675389
# 4             11.32      AR  1707675126

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'],
            edgecolor="black", marker="o", linewidth=1,
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitude vs Temperature (2-7-2024)")
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'],
            edgecolor="black", marker="o", linewidth=1,
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitude vs Humidity (%) (2-7-2024)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'],
            edgecolor="black", marker="o", linewidth=1,
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs Cloudiness (2-7-2024)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'],
            edgecolor="black", marker="o", linewidth=1,
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude vs Wind Speed (2-7-2024)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plot
def linear_regression(x,y):
    print(f"The r-value is : {(st.pearsonr(x, y)[0])}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"]>=0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 okha  53.5739  142.9478    -24.72       100          97
# 2        ponta delgada  37.7333  -25.6667     18.44        88          20
# 5             tateyama  34.9833  139.8667      5.61        81          32
# 6                tiksi  71.6872  128.8694    -34.40       100         100
# 7              klyuchi  52.2667   79.1667    -12.74        86          58
#
#          Wind Speed Country        Date
# City_ID
# 1              1.81      RU  1707675389
# 2              7.20      PT  1707675389
# 5              5.77      JP  1707675389
# 6              1.28      RU  1707675389
# 7              5.67      RU  1707675278

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"]<=0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            adamstown -25.0660 -130.1015     25.01        89          99
# 3        blackmans bay -43.0167  147.3167     14.29        89         100
# 4              ushuaia -54.8000  -68.3000      8.81        76         100
# 9            greymouth -42.4667  171.2000      8.53        90          69
# 12            trevelin -43.0858  -71.4639     18.71        42         100
#
#          Wind Speed Country        Date
# City_ID
# 0             11.31      PN  1707675265
# 3              1.36      AU  1707675389
# 4             11.32      AR  1707675126
# 9              2.26      NZ  1707675389
# 12             5.62      AR  1707675390

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
equation = linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
annotate(equation, 0, -20)
plt.title("Northern Hemisphere - City Lattitude vs Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.show()
print("There is a strong correlation between City Lattitude and Temperature in the Northen Hemisphere.")
print("Lattitudes closer to the equator (lat=0) have higher temperatures.")
print("The fit of the line is strong as indicated by the r-value of -0.85, which is close to -1.")
# Out:
# The r-value is : -0.8647453224670841
# There is a strong correlation between City Lattitude and Temperature in the Northen Hemisphere.
# Lattitudes closer to the equator (lat=0) have higher temperatures.
# The fit of the line is strong as indicated by the r-value of -0.85, which is close to -1.

# %%
# Linear regression on Southern Hemisphere
equation = linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"])
annotate(equation, -25, 16)
plt.title("Southern Hemisphere - City Lattitude vs Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.show()
print("There is a somewhat weak correlation between City Lattitude and Temperature in the Northen Hemisphere.")
print("The correlation may indicate that locations closer to lat=0 have higher temperattures.")
print("The fit of the line is weak as indicated by the r-value of 0.64, which is not close to 1.")
# Out:
# The r-value is : 0.6469668582792457
# There is a somewhat weak correlation between City Lattitude and Temperature in the Northen Hemisphere.
# The correlation may indicate that locations closer to lat=0 have higher temperattures.
# The fit of the line is weak as indicated by the r-value of 0.64, which is not close to 1.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
equation = linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"])
annotate(equation, 45, 40)
plt.title("Northern Hemisphere - City Lattitude vs Humidity (%)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()
print("There is a weak correlation between City Lattitude and Humidity in the Northen Hemisphere.")
print("The fit of the line is weak as indicated by the r-value of 0.42, which is not close to 1.")
# Out:
# The r-value is : 0.4959215413597673
# There is a weak correlation between City Lattitude and Humidity in the Northen Hemisphere.
# The fit of the line is weak as indicated by the r-value of 0.42, which is not close to 1.

# %%
# Southern Hemisphere
equation = linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"])
annotate(equation, -25, 50)
plt.title("Southern Hemisphere - City Lattitude vs Humidity (%)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.show()
print("There is almost no correlation between City Lattitude and Humidity in the Southern Hemisphere.")
print("The fit of the line is very weak as indicated by the r-value of 0.25, which is not close to 1.")
# Out:
# The r-value is : 0.15568464268576454
# There is almost no correlation between City Lattitude and Humidity in the Southern Hemisphere.
# The fit of the line is very weak as indicated by the r-value of 0.25, which is not close to 1.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
equation = linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"])
annotate(equation, 40, 25)
plt.title("Northern Hemisphere - City Lattitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()
print("There is a very weak correlation between City Lattitude and Cloudiness in the Northen Hemisphere.")
print("The fit of the line is weak as indicated by the r-value of 0.30, which is not close to 1.")
# Out:
# The r-value is : 0.30400635165517426
# There is a very weak correlation between City Lattitude and Cloudiness in the Northen Hemisphere.
# The fit of the line is weak as indicated by the r-value of 0.30, which is not close to 1.

# %%
# Southern Hemisphere
equation = linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"])
annotate(equation, -25, 50)
plt.title("Southern Hemisphere - City Lattitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()
print("There is a very weak correlation between City Lattitude and Cloudiness in the Southern Hemisphere.")
print("The fit of the line is weak as indicated by the r-value of 0.25, which is not close to 1.")
# Out:
# The r-value is : 0.253742897456094
# There is a very weak correlation between City Lattitude and Cloudiness in the Southern Hemisphere.
# The fit of the line is weak as indicated by the r-value of 0.25, which is not close to 1.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
equation = linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"])
annotate(equation, 20, 10)
plt.title("Northern Hemisphere - City Lattitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()
print("There is no correlation between City Lattitude and Windspeed in the Northern Hemisphere.")
print("The fit of the line is weak as indicated by the r-value of -0.096, which is almost zero.")
# Out:
# The r-value is : -0.09553934752104759
# There is no correlation between City Lattitude and Windspeed in the Northern Hemisphere.
# The fit of the line is weak as indicated by the r-value of -0.096, which is almost zero.

# %%
# Southern Hemisphere
equation = linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"])
annotate(equation, -50, 10)
plt.title("Southern Hemisphere - City Lattitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()
print("There is a very limited correlation between City Lattitude and Windspeed in the Southern Hemisphere.")
print("The fit of the line is weak as indicated by the r-value of -0.23, which is not close to -1.")
# Out:
# The r-value is : -0.23107675456194138
# There is a very limited correlation between City Lattitude and Windspeed in the Southern Hemisphere.
# The fit of the line is weak as indicated by the r-value of -0.23, which is not close to -1.
